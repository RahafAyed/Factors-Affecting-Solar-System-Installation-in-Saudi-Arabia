# %%
import pandas as pd
import numpy as np
import seaborn as sns                     
import matplotlib.pyplot as plt 
from plotnine import *
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_excel('datacleaning3V2.xlsx')
df.head(10)
# Out:
#             Region  Area  HouseAge  Nrooms  Nresidents  Income  AMBPS  AMBPW  \
# 0   western region   412        10       8           8   20000    700    700
# 1  southern region   350        30      13          12   20000   1300   1000
# 2   western region  1000        10       5           5    9000    500    300
# 3   eastern region   200        10       5           5   20000   1000    700
# 4  southern region   300        31      12           8    9000   1300   1000
# 5  southern region   300        20      13          12   20000    500    500
# 6   western region   450        10      13          12   13000   1300    500
# 7   western region   600        10      12          12   20000   1300    700
# 8   western region   600        10      12          12   20000   1300    700
# 9   eastern region   325        20       5           5    9000    500    300
#
#    Nconditioners  Nheaters  ...  KWattPerMonth     AreaSS     AreaSW  \
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Area', 'HouseAge', 'Nrooms', 'Nresidents', 'Income', 'AMBPS',
#        'AMBPW', 'Nconditioners', 'Nheaters', 'NwashingMachines',
#        'Nrefrigerators', 'NTV', 'Devices', 'SolarRadiation', 'AllAppliance',
#        'Lighting', 'Insulation', 'AirCT', 'BillWattsS', 'BillWattsW',
#        'KWattPerMonth', 'AreaSS', 'AreaSW', 'MaxArea', 'AnnualBill',
#        'MaxBillKW', 'KWattPerHour', 'SystemCost', 'ROI', 'ROI.1'],
#       dtype='object')

# %%
g = ggplot(df, aes(x='Income', y='AMBPS', color='Region')) +labs(
    x="Income",
    y="Avearge Bill in Summer",
    color="Region",
    title="Bills Per Income and Region",
)+ geom_line(stat='summary')
print(g)

# %%
g = ggplot(df, aes(x='Nresidents', y='AMBPS', color='Region')) +labs(
        x="Number of Residents",
        y="Avearage Bill in Summer",
        color="Region",
        title="Bills Per Number of Residents and Region",
    )+ geom_line(stat='summary')

print(g)
g = ggplot(df, aes(x='Nrooms', y='AMBPS', color='Region')) +labs(
        x="Number of Rooms",
        y="Avearage Bill in Summer",
        color="Region",
        title="Bills Per Number of Rooms and Region",
    )+ geom_line(stat='summary')

print(g)
g = ggplot(df, aes(x='Nconditioners', y='AMBPS', color='Region')) +labs(
        x="Number of Air Conditioners",
        y="Avearage Bill in Winter",
        color="Region",
        title="Bills Per Number of Air Conditioners and Region",
    )+ geom_line(stat='summary')

print(g)
g = ggplot(df, aes(x='Nrefrigerators', y='AMBPS', color='Region')) +labs(
        x="Number of Refrigerators",
        y="Avearage Bill in Summer",
        color="Region",
        title="Bills Per Number of Refrigerators and Region",
    )+ geom_line(stat='summary')

print(g)
